# 24  13669.559442  14382.232382  15185.972481  15588.337329  15826.082354
# 25   5861.401895   5759.042198   6136.058301   6242.961454   5807.838794
# 26   6180.194957   6163.791026   6676.284221   6912.110297   6955.809959
# 27   6838.936594   7191.076572   7513.491343   7947.158207   8173.338007
# 28   7386.737595   7684.779208   8030.585057   8399.694011   8674.371009
# 29  10290.378911  10574.388906  11270.471614  11563.837467  11726.769766
# 30  18389.531032  15991.108795  16094.666781  16164.161333  15690.963096
# 31  15655.936998  16766.425259  18769.787523  18825.283807  17859.931496
# 32           NaN           NaN           NaN           NaN           NaN
#
#             2020          2021
# 0   14787.635775  15781.395702
# 1    8496.424142  10636.120196
# 2   23862.710993  27478.389629
# 3   16643.806579  17225.462304
# 4    5266.876160   6228.267309
# 5    3068.812555   3345.196589
# 6    6794.489159   7507.160971
# 7   43258.263872  51987.939053
# 8   13094.459531  16265.095977
# 9    5307.215228   6104.136709
# 10  12132.876885  12472.443729
# 11   9499.590202           NaN
# 12   7003.469891   7653.171870
# 13   5645.199290   5965.132871
# 14   3903.395839   4551.184661
# 15  63530.633484  70248.629000
# 16   8437.566732   9010.572245
# 17   4604.576679   5025.542291
# 18   6863.074346   9998.544311
# 19   1283.140830   1829.593044
# 20   2354.119614   2771.717461
# 21   4897.265897   5183.581305
# 22   8655.000682  10045.680500
# 23   1863.109257   2045.535402
# 24  12569.171544  14617.604482
# 25   5353.348065   5891.499965
# 26   6056.343903   6621.574336
# 27   7167.919159   8476.752157
# 28   8335.256476   8666.387041
# 29   8458.162761   9414.226231
# 30  13871.798219  16032.502768
# 31  15619.542656  17313.188348
# 32           NaN           NaN

# %%
df_pbi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  33 non-null     object
#  1   2007     33 non-null     float64
#  2   2008     33 non-null     float64
#  3   2009     33 non-null     float64
#  4   2010     33 non-null     float64
#  5   2011     33 non-null     float64
#  6   2012     33 non-null     float64
#  7   2013     33 non-null     float64
#  8   2014     33 non-null     float64
#  9   2015     32 non-null     float64
#  10  2016     32 non-null     float64
#  11  2017     32 non-null     float64
#  12  2018     32 non-null     float64
#  13  2019     32 non-null     float64
#  14  2020     32 non-null     float64
#  15  2021     31 non-null     float64
# dtypes: float64(15), object(1)
# memory usage: 4.2+ KB

# %%
#Contamos los nulos por columnas, 
print(df_pbi.isna().sum(axis=0))
# Out:
# country    0
# 2007       0
# 2008       0
# 2009       0
# 2010       0
# 2011       0
# 2012       0
# 2013       0
# 2014       0
# 2015       1
# 2016       1
# 2017       1
# 2018       1
# 2019       1
# 2020       1
# 2021       2
# dtype: int64

# %%
# analisis de distribucion

# %%
# histogramas

# %%
df_pbi.hist(bins=32, figsize=(30,20))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))
df_pbi.plot(kind='density', ax=ax)
ax.set_xlabel('Inflación')
plt.show()

# %%
# Crear la gráfica de violín con los datos rotados del eje X
ax = sns.violinplot(data=df_pbi.drop(columns='country'), inner='stick')
plt.xticks(rotation=90)
plt.show()

# %%
#diagrama de lineas 

fig, ax = plt.subplots(figsize=(40,15))

for country in df_pbi['country']:
    ax.plot(df_pbi.columns[1:], df_pbi[df_pbi['country'] == country].values[0][1:], label=country)

ax.legend()
ax.set_xlabel('Años')
ax.set_ylabel('Crecimiento de migrantes (%)')
ax.set_title('Crecimiento migrantes por país')
plt.show()

# %%
# diagrama de barras 


# calcular la inflación promedio de cada país en los años 2007 - 2021
inflacion_anual = df_pbi[['country', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']].groupby('country').mean().reset_index()

# crear el gráfico de barras apiladas
fig, ax = plt.subplots(figsize=(20,8))
ax.bar(inflacion_anual['country'], inflacion_anual['2007'], label='2007')
ax.bar(inflacion_anual['country'], inflacion_anual['2008'], bottom=inflacion_anual['2007'], label='2008')
ax.bar(inflacion_anual['country'], inflacion_anual['2009'], bottom=inflacion_anual['2007']+inflacion_anual['2008']+inflacion_anual['2009'], label='2009')
ax.bar(inflacion_anual['country'], inflacion_anual['2010'], bottom=inflacion_anual['2007']+inflacion_anual['2008']+inflacion_anual['2009']+inflacion_anual['2010'], label='2010')
ax.bar(inflacion_anual['country'], inflacion_anual['2011'], bottom=inflacion_anual['2007']+inflacion_anual['2008']+inflacion_anual['2009']+inflacion_anual['2010']+inflacion_anual['2011'], label='2011')
ax.bar(inflacion_anual['country'], inflacion_anual['2012'], bottom=inflacion_anual['2007']+inflacion_anual['2008']+inflacion_anual['2009']+inflacion_anual['2010']+inflacion_anual['2011']+inflacion_anual['2011'], label='2012')
ax.bar(inflacion_anual['country'], inflacion_anual['2013'], bottom=inflacion_anual['2007']+inflacion_anual['2008']+inflacion_anual['2009']+inflacion_anual['2010']+inflacion_anual['2011']+inflacion_anual['2012'], label='2013')
ax.bar(inflacion_anual['country'], inflacion_anual['2014'], bottom=inflacion_anual['2007']+inflacion_anual['2008']+inflacion_anual['2009']+inflacion_anual['2010']+inflacion_anual['2011']+inflacion_anual['2012']+inflacion_anual['2013'], label='2014')
ax.bar(inflacion_anual['country'], inflacion_anual['2015'], bottom=inflacion_anual['2007']+inflacion_anual['2008']+inflacion_anual['2009']+inflacion_anual['2010']+inflacion_anual['2011']+inflacion_anual['2012']+inflacion_anual['2013']+inflacion_anual['2014'], label='2015')
ax.bar(inflacion_anual['country'], inflacion_anual['2016'], bottom=inflacion_anual['2007']+inflacion_anual['2008']+inflacion_anual['2009']+inflacion_anual['2010']+inflacion_anual['2011']+inflacion_anual['2012']+inflacion_anual['2013']+inflacion_anual['2014']+inflacion_anual['2015'], label='2016')
ax.bar(inflacion_anual['country'], inflacion_anual['2017'], bottom=inflacion_anual['2007']+inflacion_anual['2008']+inflacion_anual['2009']+inflacion_anual['2010']+inflacion_anual['2011']+inflacion_anual['2012']+inflacion_anual['2013']+inflacion_anual['2014']+inflacion_anual['2015']+inflacion_anual['2016'], label='2017')
ax.bar(inflacion_anual['country'], inflacion_anual['2018'], bottom=inflacion_anual['2007']+inflacion_anual['2008']+inflacion_anual['2009']+inflacion_anual['2010']+inflacion_anual['2011']+inflacion_anual['2012']+inflacion_anual['2013']+inflacion_anual['2014']+inflacion_anual['2015']+inflacion_anual['2016']+inflacion_anual['2017'], label='2018')
ax.bar(inflacion_anual['country'], inflacion_anual['2019'], bottom=inflacion_anual['2007']+inflacion_anual['2008']+inflacion_anual['2009']+inflacion_anual['2010']+inflacion_anual['2011']+inflacion_anual['2012']+inflacion_anual['2013']+inflacion_anual['2014']+inflacion_anual['2015']+inflacion_anual['2016']+inflacion_anual['2017']+inflacion_anual['2018'], label='2019')
ax.bar(inflacion_anual['country'], inflacion_anual['2020'], bottom=inflacion_anual['2007']+inflacion_anual['2008']+inflacion_anual['2009']+inflacion_anual['2010']+inflacion_anual['2011']+inflacion_anual['2012']+inflacion_anual['2013']+inflacion_anual['2014']+inflacion_anual['2015']+inflacion_anual['2016']+inflacion_anual['2017']+inflacion_anual['2018']+inflacion_anual['2019'], label='2020')
ax.bar(inflacion_anual['country'], inflacion_anual['2021'], bottom=inflacion_anual['2007']+inflacion_anual['2008']+inflacion_anual['2009']+inflacion_anual['2010']+inflacion_anual['2011']+inflacion_anual['2012']+inflacion_anual['2013']+inflacion_anual['2014']+inflacion_anual['2015']+inflacion_anual['2016']+inflacion_anual['2017']+inflacion_anual['2018']+inflacion_anual['2019']+inflacion_anual['2020'], label='2021')


# personalizar el gráfico
ax.set_xlabel('País')
ax.set_ylabel('Inflación (%)')
ax.set_title('Inflación promedio por país en 2007 a 2021')
ax.legend()

ax.tick_params(axis='x', labelrotation=90)

# mostrar el gráfico
plt.show()

# %%
# analisis de outliers

# %%
# Creamos un boxplot de Seaborn:

plt.figure(figsize=(10, 8))

sns.boxplot(data=df_pbi.iloc[:,1:])

# Mostramos el gráfico:

plt.show()

# %%
# Definimos una función para encontrar outliers
def find_outliers(data):
    # Calculamos el rango intercuartílico
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    
    # Calculamos los límites del bigote
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Encontramos los outliers
    outliers = data[(data < lower_bound) | (data > upper_bound)]
    
    # Devolvemos los outliers
    return outliers

# Buscamos los outliers en cada columna del DataFrame
for col in df_pbi.columns[1:]:
    outliers = find_outliers(df_pbi[col])
    print("Outliers en la columna", col, ":", outliers.values)
# Out:
# Outliers en la columna 2007 : [16006.13611075 29687.86521503 17219.04868039 44659.8951408
#  48050.22377711 15627.28681791]
# Outliers en la columna 2008 : [29013.63028708 46710.5055759  48570.04598046 20011.14827405]
# Outliers en la columna 2009 : [27120.69054521 40876.31015403 47194.94335473]
# Outliers en la columna 2010 : [27046.65766519 47562.08342531 48650.64312833]
# Outliers en la columna 2011 : [26644.92657759 52223.69611236 50065.96650417]
# Outliers en la columna 2012 : [28059.65539534 52669.08996323 51784.41857388]
# Outliers en la columna 2013 : [27389.6019707  52635.17495804 53291.12768914]
# Outliers en la columna 2014 : [28720.66219345 50955.99832324 55123.8497869 ]
# Outliers en la columna 2015 : [30206.24043474 43596.13553655 56762.7294516 ]
# Outliers en la columna 2016 : [29887.16487868 42315.60370568 57866.74493411]
# Outliers en la columna 2017 : [30969.87619668 45129.42929809 59907.75426088]
# Outliers en la columna 2018 : [31738.267157   46548.63841083 62823.3094382 ]
# Outliers en la columna 2019 : [32610.48504908 46328.67184085 65120.39466287]
# Outliers en la columna 2020 : [23862.71099291 43258.26387156 63530.63348391]
# Outliers en la columna 2021 : [51987.93905297 70248.62900022]

# %%
def find_outliers(data):
    # Calculamos el rango intercuartílico
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    
    # Calculamos los límites del bigote
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Encontramos los outliers y sus índices correspondientes
    outliers = data[(data < lower_bound) | (data > upper_bound)]
    outlier_indices = outliers.index
    
    # Devolvemos los outliers y sus índices correspondientes
    return outliers, outlier_indices

# %%
for col in df_pbi.columns[1:]:
    outliers, outlier_indices = find_outliers(df_pbi[col])
    print("Outliers en la columna", col)
    print("Valores:", outliers.values)
    print("Índices:", outlier_indices.values)
    print("Países:", df_pbi.loc[outlier_indices]['country'].values)
    print("")
# Out:
# Outliers en la columna 2007
# Valores: [16006.13611075 29687.86521503 17219.04868039 44659.8951408
#  48050.22377711 15627.28681791]
# Índices: [ 0  2  3  7 15 30]
# Países: ['Antigua y Barbuda' 'Bahamas' 'Barbados' 'Canadá' 'Estados Unidos'
#  'Trinidad y Tobago']
#
# Outliers en la columna 2008
# Valores: [29013.63028708 46710.5055759  48570.04598046 20011.14827405]
# Índices: [ 2  7 15 30]
# Países: ['Bahamas' 'Canadá' 'Estados Unidos' 'Trinidad y Tobago']
#
# Outliers en la columna 2009
# Valores: [27120.69054521 40876.31015403 47194.94335473]
# Índices: [ 2  7 15]
# Países: ['Bahamas' 'Canadá' 'Estados Unidos']
#
# Outliers en la columna 2010
# Valores: [27046.65766519 47562.08342531 48650.64312833]
# Índices: [ 2  7 15]
# Países: ['Bahamas' 'Canadá' 'Estados Unidos']
#
# Outliers en la columna 2011
# Valores: [26644.92657759 52223.69611236 50065.96650417]
# Índices: [ 2  7 15]
# Países: ['Bahamas' 'Canadá' 'Estados Unidos']
#
# Outliers en la columna 2012
# Valores: [28059.65539534 52669.08996323 51784.41857388]
# Índices: [ 2  7 15]
# Países: ['Bahamas' 'Canadá' 'Estados Unidos']
#
# Outliers en la columna 2013
# Valores: [27389.6019707  52635.17495804 53291.12768914]
# Índices: [ 2  7 15]
# Países: ['Bahamas' 'Canadá' 'Estados Unidos']
#
# Outliers en la columna 2014
# Valores: [28720.66219345 50955.99832324 55123.8497869 ]
# Índices: [ 2  7 15]
# Países: ['Bahamas' 'Canadá' 'Estados Unidos']
#
# Outliers en la columna 2015
# Valores: [30206.24043474 43596.13553655 56762.7294516 ]
# Índices: [ 2  7 15]
# Países: ['Bahamas' 'Canadá' 'Estados Unidos']
#
# Outliers en la columna 2016
# Valores: [29887.16487868 42315.60370568 57866.74493411]
# Índices: [ 2  7 15]
# Países: ['Bahamas' 'Canadá' 'Estados Unidos']
#
# Outliers en la columna 2017
# Valores: [30969.87619668 45129.42929809 59907.75426088]
# Índices: [ 2  7 15]
# Países: ['Bahamas' 'Canadá' 'Estados Unidos']
#
# Outliers en la columna 2018
# Valores: [31738.267157   46548.63841083 62823.3094382 ]
# Índices: [ 2  7 15]
# Países: ['Bahamas' 'Canadá' 'Estados Unidos']
#
# Outliers en la columna 2019
# Valores: [32610.48504908 46328.67184085 65120.39466287]
# Índices: [ 2  7 15]
# Países: ['Bahamas' 'Canadá' 'Estados Unidos']
#
# Outliers en la columna 2020
# Valores: [23862.71099291 43258.26387156 63530.63348391]
# Índices: [ 2  7 15]
# Países: ['Bahamas' 'Canadá' 'Estados Unidos']
#
# Outliers en la columna 2021
# Valores: [51987.93905297 70248.62900022]
# Índices: [ 7 15]
# Países: ['Canadá' 'Estados Unidos']

# %%
# Comprender la causa de los outliers:

# %%
# matriz de correlacion

# %%
#convertimos en datos numericos las columnas en string que vamos a necesitar.
from sklearn import preprocessing 
le = preprocessing.LabelEncoder()

# %%
#analizamos la correlacion entre las features (tabla matriz de correlacion)

df_pbi_corr = df_pbi.corr()
# Out:
# C:\Users\alekz\AppData\Local\Temp\ipykernel_33180\3245972664.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_pbi_corr = df_pbi.corr()

# %%
# visualizo
df_pbi_corr
# Out:
#           2007      2008      2009      2010      2011      2012      2013  \
# 2007  1.000000  0.996461  0.995069  0.987856  0.979533  0.979352  0.975072
# 2008  0.996461  1.000000  0.994018  0.992153  0.985821  0.986492  0.982978
# 2009  0.995069  0.994018  1.000000  0.994218  0.983742  0.985408  0.982462
# 2010  0.987856  0.992153  0.994218  1.000000  0.995787  0.996644  0.994032
# 2011  0.979533  0.985821  0.983742  0.995787  1.000000  0.998953  0.997809
# 2012  0.979352  0.986492  0.985408  0.996644  0.998953  1.000000  0.999145
# 2013  0.975072  0.982978  0.982462  0.994032  0.997809  0.999145  1.000000
# 2014  0.976520  0.985053  0.987222  0.995100  0.993444  0.996825  0.997533
# 2015  0.976979  0.979079  0.988064  0.984605  0.978531  0.983219  0.985134
# 2016  0.971402  0.971039  0.985287  0.978876  0.970903  0.975977  0.978527
# 2017  0.968627  0.969074  0.983368  0.980024  0.974097  0.978913  0.981582
# 2018  0.970846  0.969606  0.984623  0.978831  0.970942  0.976122  0.978942
# 2019  0.971008  0.967656  0.984426  0.974653  0.963972  0.969228  0.971867
# 2020  0.956606  0.954179  0.972234  0.964900  0.956273  0.960947  0.965408
# 2021  0.962281  0.961108  0.976335  0.973449  0.966999  0.971421  0.975017
#
#           2014      2015      2016      2017      2018      2019      2020  \
# 2007  0.976520  0.976979  0.971402  0.968627  0.970846  0.971008  0.956606
# 2008  0.985053  0.979079  0.971039  0.969074  0.969606  0.967656  0.954179
# 2009  0.987222  0.988064  0.985287  0.983368  0.984623  0.984426  0.972234
# 2010  0.995100  0.984605  0.978876  0.980024  0.978831  0.974653  0.964900
# 2011  0.993444  0.978531  0.970903  0.974097  0.970942  0.963972  0.956273
# 2012  0.996825  0.983219  0.975977  0.978913  0.976122  0.969228  0.960947
